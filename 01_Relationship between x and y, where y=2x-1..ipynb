# %% [markdown]
# # Imports

# %% [markdown]
# We start with imports.
#
# Here we are importing TensorFlow and calling it tf for ease of use.
#
# We then import a library - numpy.
#
# This library will help us to represent our data as lists easily and quickly.
#
# Then we import a framework - keras.
#
# This will help us define a neural network as a set of Sequential layers.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# # Define the Neural Network

# %% [markdown]
# This neural network has 1 layer, and that layer has 1 neuron, and the input shape to it is just 1 value.

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %% [markdown]
# # Compile the Neural Network

# %% [markdown]
# While compiling our Neural Network we have to specify two functions, a loss and an optimizer.
#
# We know that in our function, the relationship between the numbers is y=2x-1.
#
# Computer makes a guess while trying to learn this relationship.
#
# The LOSS function measures the guessed answers against the known correct answers and measures how well or how badly it did.
#
# It then uses OPTIMIZER function to make another guess. Based on how the loss function went, it will try to minimize the loss.
#
# Here, we are using 'MEAN SQUARED ERROR' for the loss and 'STOCHASTIC GRADIENT DESCENT' for the optimizer.

# %%
model.compile(optimizer = 'sgd', loss = 'mean_squared_error')

# %% [markdown]
# # Providing the Data

# %% [markdown]
# Now, we will feed in some data. We are providing 6xs and 6ys. The relationship between these is y=2x-1.

# %%
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %% [markdown]
# # Training the Neural Network

# %% [markdown]
# We train the neural network in model.fit. Here it learns the relationship between x and y.
#
# It will go through the "OPTIMIZER" and "LOSS" loop for the number of epochs we specify.
#
# Neural network deals with probabilities.

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 209ms/step - loss: 38.8261
# Epoch 2/500
# 1/1 [==============================] - 0s 2ms/step - loss: 30.8967
# Epoch 3/500
# 1/1 [==============================] - 0s 3ms/step - loss: 24.6510
# Epoch 4/500
# 1/1 [==============================] - 0s 3ms/step - loss: 19.7301
# Epoch 5/500
# 1/1 [==============================] - 0s 5ms/step - loss: 15.8517
# Epoch 6/500
# 1/1 [==============================] - 0s 4ms/step - loss: 12.7936
# Epoch 7/500
# 1/1 [==============================] - 0s 3ms/step - loss: 10.3811
# Epoch 8/500
# 1/1 [==============================] - 0s 3ms/step - loss: 8.4765
# Epoch 9/500
# 1/1 [==============================] - 0s 2ms/step - loss: 6.9717
# Epoch 10/500
# 1/1 [==============================] - 0s 4ms/step - loss: 5.7816
# Epoch 11/500
# 1/1 [==============================] - 0s 7ms/step - loss: 4.8392
# Epoch 12/500
# 1/1 [==============================] - 0s 2ms/step - loss: 4.0917
# ...

# %% [markdown]
# # Evaluate the Model

# %% [markdown]
# Now, we have a model which has learned the relationship between x and y.
#
# We are using model.predict method to figure out the y by providing it the value of x.

# %%
print(model.predict([10.0]))
# Out:
# [[18.977827]]
